# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
#!pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key
temp_units = "imperial"
#imperial for farenheight 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#lists for the dataframe
cities_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            cities_two.append(city)
        else:
            count_one += 1
            cities_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | muros
# Processing Record 2 of Set 1 | tessalit
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | alice springs
# Processing Record 9 of Set 1 | luanda
# City not found. Skipping...
# Processing Record 10 of Set 1 | georgetown
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | vila
# Processing Record 16 of Set 1 | semnan
# Processing Record 17 of Set 1 | ipixuna
# Processing Record 18 of Set 1 | lazaro cardenas
# Processing Record 19 of Set 1 | mundra
# Processing Record 20 of Set 1 | alveringem
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | aswan
# Processing Record 23 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | rurrenabaque
# Processing Record 26 of Set 1 | katete
# Processing Record 27 of Set 1 | wanaka
# City not found. Skipping...
# Processing Record 28 of Set 1 | hasaki
# Processing Record 29 of Set 1 | beian
# Processing Record 30 of Set 1 | buala
# Processing Record 31 of Set 1 | tuatapere
# Processing Record 32 of Set 1 | sola
# Processing Record 33 of Set 1 | jalu
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | wad madani
# City not found. Skipping...
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | linares
# Processing Record 39 of Set 1 | komsomolskiy
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | arvika
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 1 | faya
# Processing Record 44 of Set 1 | mapiripan
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | capoterra
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | college
# Processing Record 1 of Set 2 | matagami
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | pascagoula
# Processing Record 5 of Set 2 | sakakah
# Processing Record 6 of Set 2 | dingle
# Processing Record 7 of Set 2 | beringovskiy
# Processing Record 8 of Set 2 | mount gambier
# Processing Record 9 of Set 2 | rikitea
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | pokaran
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | sao filipe
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | lerwick
# Processing Record 18 of Set 2 | ganzhou
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | najran
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | sioux lookout
# Processing Record 25 of Set 2 | nioro
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | natchitoches
# Processing Record 29 of Set 2 | dongsheng
# Processing Record 30 of Set 2 | mindelo
# Processing Record 31 of Set 2 | esperance
# Processing Record 32 of Set 2 | shubarshi
# Processing Record 33 of Set 2 | bredasdorp
# City not found. Skipping...
# Processing Record 34 of Set 2 | chongqing
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | natal
# Processing Record 37 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 38 of Set 2 | half moon bay
# Processing Record 39 of Set 2 | gambela
# Processing Record 40 of Set 2 | palora
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | nome
# Processing Record 43 of Set 2 | tiznit
# Processing Record 44 of Set 2 | arlit
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | lufilufi
# City not found. Skipping...
# Processing Record 47 of Set 2 | martinsville
# Processing Record 48 of Set 2 | shingu
# Processing Record 49 of Set 2 | berlevag
# Processing Record 1 of Set 3 | freeport
# Processing Record 2 of Set 3 | hilsa
# Processing Record 3 of Set 3 | iqaluit
# Processing Record 4 of Set 3 | saint-joseph
# Processing Record 5 of Set 3 | beloha
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | nata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 3 | taga
# City not found. Skipping...
# Processing Record 9 of Set 3 | itapirapua
# Processing Record 10 of Set 3 | bajil
# Processing Record 11 of Set 3 | geraldton
# Processing Record 12 of Set 3 | shetpe
# Processing Record 13 of Set 3 | olinda
# Processing Record 14 of Set 3 | durg
# City not found. Skipping...
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | vila franca do campo
# Processing Record 19 of Set 3 | katobu
# Processing Record 20 of Set 3 | hamilton
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | san francisco
# Processing Record 23 of Set 3 | fortuna
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | hilo
# City not found. Skipping...
# Processing Record 27 of Set 3 | barra do garcas
# Processing Record 28 of Set 3 | san policarpo
# Processing Record 29 of Set 3 | mangan
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | yinchuan
# Processing Record 32 of Set 3 | estevan
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | susa
# City not found. Skipping...
# Processing Record 35 of Set 3 | blois
# Processing Record 36 of Set 3 | nauta
# Processing Record 37 of Set 3 | sitka
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | sanford
# Processing Record 41 of Set 3 | mitsamiouli
# Processing Record 42 of Set 3 | clyde river
# Processing Record 43 of Set 3 | san javier
# Processing Record 44 of Set 3 | sept-iles
# Processing Record 45 of Set 3 | leningradskiy
# Processing Record 46 of Set 3 | manaure
# Processing Record 47 of Set 3 | brae
# Processing Record 48 of Set 3 | russell
# Processing Record 49 of Set 3 | carnarvon
# City not found. Skipping...
# Processing Record 1 of Set 4 | burnie
# Processing Record 2 of Set 4 | east london
# City not found. Skipping...
# Processing Record 3 of Set 4 | hervey bay
# Processing Record 4 of Set 4 | tevriz
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | kanniyakumari
# Processing Record 7 of Set 4 | constitucion
# Processing Record 8 of Set 4 | rorvik
# Processing Record 9 of Set 4 | aranos
# Processing Record 10 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 4 | olafsvik
# Processing Record 12 of Set 4 | radviliskis
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 4 | vanimo
# City not found. Skipping...
# Processing Record 14 of Set 4 | aquiraz
# Processing Record 15 of Set 4 | narsaq
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 4 | mweka
# Processing Record 19 of Set 4 | touros
# City not found. Skipping...
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | pontes e lacerda
# Processing Record 22 of Set 4 | kutum
# Processing Record 23 of Set 4 | tecoanapa
# Processing Record 24 of Set 4 | beruwala
# Processing Record 25 of Set 4 | erzin
# Processing Record 26 of Set 4 | pata
# City not found. Skipping...
# Processing Record 27 of Set 4 | poum
# Processing Record 28 of Set 4 | kavieng
# Processing Record 29 of Set 4 | urubicha
# Processing Record 30 of Set 4 | mahebourg
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | rio de jesus
# Processing Record 33 of Set 4 | boyolangu
# Processing Record 34 of Set 4 | mogadishu
# Processing Record 35 of Set 4 | hattiesburg
# Processing Record 36 of Set 4 | lang son
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | yuanping
# Processing Record 39 of Set 4 | qaqortoq
# Processing Record 40 of Set 4 | hearst
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | kichera
# Processing Record 43 of Set 4 | amapa
# Processing Record 44 of Set 4 | samarai
# Processing Record 45 of Set 4 | qaanaaq
# Processing Record 46 of Set 4 | amuntai
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | airai
# City not found. Skipping...
# Processing Record 49 of Set 4 | laguna
# Processing Record 1 of Set 5 | richards bay
# Processing Record 2 of Set 5 | port elizabeth
# Processing Record 3 of Set 5 | shelburne
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | sterling
# Processing Record 6 of Set 5 | kyzyl-suu
# Processing Record 7 of Set 5 | moses lake
# Processing Record 8 of Set 5 | mehran
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | adrar
# Processing Record 11 of Set 5 | garissa
# Processing Record 12 of Set 5 | saint-pierre
# Processing Record 13 of Set 5 | ust-omchug
# Processing Record 14 of Set 5 | vuktyl
# Processing Record 15 of Set 5 | praia da vitoria
# Processing Record 16 of Set 5 | zhigansk
# City not found. Skipping...
# Processing Record 17 of Set 5 | veraval
# Processing Record 18 of Set 5 | puerto carreno
# Processing Record 19 of Set 5 | campanha
# Processing Record 20 of Set 5 | kuito
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | muravlenko
# Processing Record 23 of Set 5 | castro
# Processing Record 24 of Set 5 | vytegra
# Processing Record 25 of Set 5 | van
# Processing Record 26 of Set 5 | okhotsk
# Processing Record 27 of Set 5 | takoradi
# Processing Record 28 of Set 5 | nanortalik
# Processing Record 29 of Set 5 | caravelas
# Processing Record 30 of Set 5 | kysyl-syr
# Processing Record 31 of Set 5 | tandil
# Processing Record 32 of Set 5 | santarem
# Processing Record 33 of Set 5 | buncrana
# Processing Record 34 of Set 5 | norrkoping
# Processing Record 35 of Set 5 | hastings
# City not found. Skipping...
# Processing Record 36 of Set 5 | verkhnyaya inta
# Processing Record 37 of Set 5 | cidreira
# Processing Record 38 of Set 5 | virginia beach
# Processing Record 39 of Set 5 | hohhot
# Processing Record 40 of Set 5 | husavik
# City not found. Skipping...
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | karratha
# Processing Record 43 of Set 5 | acapulco
# Processing Record 44 of Set 5 | martapura
# Processing Record 45 of Set 5 | brookfield
# Processing Record 46 of Set 5 | curillo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 5 | jam sahib
# City not found. Skipping...
# Processing Record 48 of Set 5 | urusha
# Processing Record 49 of Set 5 | bacolod
# Processing Record 1 of Set 6 | mandalgovi
# Processing Record 2 of Set 6 | rio verde de mato grosso
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | ambilobe
# Processing Record 5 of Set 6 | nesbyen
# Processing Record 6 of Set 6 | tefe
# Processing Record 7 of Set 6 | bandarbeyla
# Processing Record 8 of Set 6 | srednekolymsk
# Processing Record 9 of Set 6 | aras
# Processing Record 10 of Set 6 | pemba
# Processing Record 11 of Set 6 | ostrovnoy
# Processing Record 12 of Set 6 | srandakan
# Processing Record 13 of Set 6 | sao tome
# Processing Record 14 of Set 6 | norman wells
# Processing Record 15 of Set 6 | gao
# Processing Record 16 of Set 6 | nades
# Processing Record 17 of Set 6 | lavrentiya
# Processing Record 18 of Set 6 | pisco
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | caohai
# Processing Record 21 of Set 6 | flagstaff
# Processing Record 22 of Set 6 | takayama
# Processing Record 23 of Set 6 | dolores
# Processing Record 24 of Set 6 | bressuire
# Processing Record 25 of Set 6 | inzer
# Processing Record 26 of Set 6 | moroto
# Processing Record 27 of Set 6 | port-gentil
# Processing Record 28 of Set 6 | birao
# Processing Record 29 of Set 6 | ust-nera
# Processing Record 30 of Set 6 | comodoro rivadavia
# Processing Record 31 of Set 6 | gumdag
# City not found. Skipping...
# Processing Record 32 of Set 6 | scottsbluff
# Processing Record 33 of Set 6 | bushehr
# Processing Record 34 of Set 6 | unguia
# Processing Record 35 of Set 6 | venado tuerto
# Processing Record 36 of Set 6 | tiradentes
# Processing Record 37 of Set 6 | tuni
# Processing Record 38 of Set 6 | saint-francois
# Processing Record 39 of Set 6 | deputatskiy
# Processing Record 40 of Set 6 | nikolskoye
# City not found. Skipping...
# Processing Record 41 of Set 6 | ndjole
# Processing Record 42 of Set 6 | shimoda
# Processing Record 43 of Set 6 | cherskiy
# Processing Record 44 of Set 6 | wharton
# City not found. Skipping...
# Processing Record 45 of Set 6 | matara
# Processing Record 46 of Set 6 | araouane
# Processing Record 47 of Set 6 | jimma
# Processing Record 48 of Set 6 | talnakh
# Processing Record 49 of Set 6 | karpathos
# Processing Record 1 of Set 7 | tari
# Processing Record 2 of Set 7 | kavaratti
# Processing Record 3 of Set 7 | marawi
# Processing Record 4 of Set 7 | baykit
# City not found. Skipping...
# Processing Record 5 of Set 7 | brigantine
# Processing Record 6 of Set 7 | svetlyy
# Processing Record 7 of Set 7 | akyab
# Processing Record 8 of Set 7 | mys shmidta
# Processing Record 9 of Set 7 | saint-georges
# Processing Record 10 of Set 7 | isangel
# Processing Record 11 of Set 7 | ozinki
# Processing Record 12 of Set 7 | bani walid
# Processing Record 13 of Set 7 | lensk
# City not found. Skipping...
# Processing Record 14 of Set 7 | tamasopo
# Processing Record 15 of Set 7 | oga
# City not found. Skipping...
# Processing Record 16 of Set 7 | bouake
# Processing Record 17 of Set 7 | hays
# Processing Record 18 of Set 7 | sao domingos
# Processing Record 19 of Set 7 | seoul
# Processing Record 20 of Set 7 | mogadouro
# Processing Record 21 of Set 7 | jiguani
# Processing Record 22 of Set 7 | portmore
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 7 | hami
# Processing Record 24 of Set 7 | sanary-sur-mer
# Processing Record 25 of Set 7 | nuevo progreso
# Processing Record 26 of Set 7 | emerald
# Processing Record 27 of Set 7 | peru
# Processing Record 28 of Set 7 | santa maria
# City not found. Skipping...
# Processing Record 29 of Set 7 | goderich
# Processing Record 30 of Set 7 | cruzeiro do sul
# Processing Record 31 of Set 7 | lata
# Processing Record 32 of Set 7 | marsh harbour
# Processing Record 33 of Set 7 | flinders
# Processing Record 34 of Set 7 | villanueva
# Processing Record 35 of Set 7 | kodinsk
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | okato
# Processing Record 38 of Set 7 | salinas
# Processing Record 39 of Set 7 | manokwari
# Processing Record 40 of Set 7 | calan
# Processing Record 41 of Set 7 | port augusta
# City not found. Skipping...
# Processing Record 42 of Set 7 | namatanai
# Processing Record 43 of Set 7 | alofi
# Processing Record 44 of Set 7 | port blair
# Processing Record 45 of Set 7 | thohoyandou
# Processing Record 46 of Set 7 | dunn
# Processing Record 47 of Set 7 | bathsheba
# Processing Record 48 of Set 7 | aden
# Processing Record 49 of Set 7 | roald
# Processing Record 1 of Set 8 | biak
# Processing Record 2 of Set 8 | guerrero negro
# Processing Record 3 of Set 8 | tura
# Processing Record 4 of Set 8 | cabanas
# Processing Record 5 of Set 8 | bereda
# Processing Record 6 of Set 8 | santa rosa
# Processing Record 7 of Set 8 | sisimiut
# Processing Record 8 of Set 8 | cabadiangan
# Processing Record 9 of Set 8 | bassano
# Processing Record 10 of Set 8 | waipawa
# Processing Record 11 of Set 8 | syracuse
# Processing Record 12 of Set 8 | yar-sale
# Processing Record 13 of Set 8 | anderson
# Processing Record 14 of Set 8 | lexington
# Processing Record 15 of Set 8 | nizhniy ingash
# Processing Record 16 of Set 8 | minab
# Processing Record 17 of Set 8 | parksville
# Processing Record 18 of Set 8 | cabedelo
# City not found. Skipping...
# Processing Record 19 of Set 8 | kuala terengganu
# Processing Record 20 of Set 8 | sao sebastiao
# Processing Record 21 of Set 8 | azul
# Processing Record 22 of Set 8 | valparaiso
# Processing Record 23 of Set 8 | tanout
# Processing Record 24 of Set 8 | jyvaskyla
# Processing Record 25 of Set 8 | pangnirtung
# Processing Record 26 of Set 8 | muzhi
# Processing Record 27 of Set 8 | port hedland
# Processing Record 28 of Set 8 | kropotkin
# Processing Record 29 of Set 8 | paysandu
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | mitu
# Processing Record 32 of Set 8 | rawson
# Processing Record 33 of Set 8 | bhuban
# City not found. Skipping...
# Processing Record 34 of Set 8 | mizdah
# Processing Record 35 of Set 8 | letka
# Processing Record 36 of Set 8 | baiyin
# Processing Record 37 of Set 8 | svarstad
# Processing Record 38 of Set 8 | kiama
# Processing Record 39 of Set 8 | eyl
# Processing Record 40 of Set 8 | monte alegre
# Processing Record 41 of Set 8 | aklavik
# Processing Record 42 of Set 8 | aykhal
# Processing Record 43 of Set 8 | wonthaggi
# Processing Record 44 of Set 8 | san ignacio
# Processing Record 45 of Set 8 | hammerfest
# Processing Record 46 of Set 8 | jumla
# Processing Record 47 of Set 8 | hambantota
# Processing Record 48 of Set 8 | tabou
# Processing Record 49 of Set 8 | benjamin constant
# Processing Record 1 of Set 9 | ishigaki
# Processing Record 2 of Set 9 | jiwani
# Processing Record 3 of Set 9 | san quintin
# City not found. Skipping...
# Processing Record 4 of Set 9 | machilipatnam
# Processing Record 5 of Set 9 | vestmannaeyjar
# Processing Record 6 of Set 9 | rujiena
# Processing Record 7 of Set 9 | viru
# Processing Record 8 of Set 9 | antibes
# Processing Record 9 of Set 9 | vanavara
# Processing Record 10 of Set 9 | tual
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 9 | samana
# Processing Record 12 of Set 9 | kuryk
# Processing Record 13 of Set 9 | masterton
# Processing Record 14 of Set 9 | ribas do rio pardo
# Processing Record 15 of Set 9 | barcelona
# City not found. Skipping...
# Processing Record 16 of Set 9 | sibolga
# Processing Record 17 of Set 9 | kirakira
# Processing Record 18 of Set 9 | vardo
# Processing Record 19 of Set 9 | zanjan
# Processing Record 20 of Set 9 | pimentel
# Processing Record 21 of Set 9 | chiredzi
# City not found. Skipping...
# Processing Record 22 of Set 9 | yaan
# Processing Record 23 of Set 9 | zabid
# Processing Record 24 of Set 9 | ketchikan
# Processing Record 25 of Set 9 | tilichiki
# City not found. Skipping...
# Processing Record 26 of Set 9 | ringas
# City not found. Skipping...
# Processing Record 27 of Set 9 | bilibino
# Processing Record 28 of Set 9 | codrington
# Processing Record 29 of Set 9 | santa barbara
# Processing Record 30 of Set 9 | torbay
# Processing Record 31 of Set 9 | northam
# Processing Record 32 of Set 9 | martan-chu
# Processing Record 33 of Set 9 | aasiaat
# City not found. Skipping...
# Processing Record 34 of Set 9 | nemuro
# Processing Record 35 of Set 9 | hovd
# City not found. Skipping...
# Processing Record 36 of Set 9 | griffith
# Processing Record 37 of Set 9 | obo
# Processing Record 38 of Set 9 | dakar
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | itaituba
# Processing Record 41 of Set 9 | bosaso
# Processing Record 42 of Set 9 | portland
# Processing Record 43 of Set 9 | shchelkun
# Processing Record 44 of Set 9 | elizabeth city
# City not found. Skipping...
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | bulgan
# Processing Record 47 of Set 9 | maniago
# Processing Record 48 of Set 9 | tailai
# Processing Record 49 of Set 9 | amazar
# Processing Record 1 of Set 10 | asahikawa
# Processing Record 2 of Set 10 | buhe
# Processing Record 3 of Set 10 | bairiki
# Processing Record 4 of Set 10 | lorengau
# Processing Record 5 of Set 10 | milton
# Processing Record 6 of Set 10 | fairbanks
# Processing Record 7 of Set 10 | mirnyy
# Processing Record 8 of Set 10 | egvekinot
# Processing Record 9 of Set 10 | tshane
# Processing Record 10 of Set 10 | ugento
# Processing Record 11 of Set 10 | mattru
# Processing Record 12 of Set 10 | caluquembe
# Processing Record 13 of Set 10 | abay
# City not found. Skipping...
# Processing Record 14 of Set 10 | borba
# Processing Record 15 of Set 10 | assesse
# Processing Record 16 of Set 10 | glendive
# Processing Record 17 of Set 10 | beisfjord
# Processing Record 18 of Set 10 | tsogni
# Processing Record 19 of Set 10 | rocha
# Processing Record 20 of Set 10 | turukhansk
# Processing Record 21 of Set 10 | zabol
# Processing Record 22 of Set 10 | maniitsoq
# Processing Record 23 of Set 10 | mingguang
# Processing Record 24 of Set 10 | heide
# Processing Record 25 of Set 10 | coihaique
# Processing Record 26 of Set 10 | semirom
# Processing Record 27 of Set 10 | monterey
# Processing Record 28 of Set 10 | awjilah
# Processing Record 29 of Set 10 | sovetskiy
# Processing Record 30 of Set 10 | kadoma
# Processing Record 31 of Set 10 | shanhetun
# Processing Record 32 of Set 10 | khorixas
# Processing Record 33 of Set 10 | makueni
# Processing Record 34 of Set 10 | tondon
# Processing Record 35 of Set 10 | honningsvag
# Processing Record 36 of Set 10 | mareeba
# City not found. Skipping...
# Processing Record 37 of Set 10 | west helena
# Processing Record 38 of Set 10 | anastacio
# Processing Record 39 of Set 10 | ipora
# Processing Record 40 of Set 10 | uzhur
# Processing Record 41 of Set 10 | babayurt
# Processing Record 42 of Set 10 | poroshkovo
# Processing Record 43 of Set 10 | makakilo city
# Processing Record 44 of Set 10 | afua
# Processing Record 45 of Set 10 | kargasok
# Processing Record 46 of Set 10 | grand river south east
# Processing Record 47 of Set 10 | turayf
# Processing Record 48 of Set 10 | porbandar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 10 | goroka
# Processing Record 1 of Set 11 | kaduy
# Processing Record 2 of Set 11 | savelugu
# Processing Record 3 of Set 11 | crixas
# Processing Record 4 of Set 11 | hobyo
# Processing Record 5 of Set 11 | haveri
# Processing Record 6 of Set 11 | sindor
# Processing Record 7 of Set 11 | belaya gora
# Processing Record 8 of Set 11 | cockburn town
# Processing Record 9 of Set 11 | nabire
# Processing Record 10 of Set 11 | buraydah
# Processing Record 11 of Set 11 | bjornevatn
# Processing Record 12 of Set 11 | terney
# Processing Record 13 of Set 11 | paamiut
# Processing Record 14 of Set 11 | katsuura
# Processing Record 15 of Set 11 | sarankhola
# Processing Record 16 of Set 11 | basco
# Processing Record 17 of Set 11 | fort nelson
# Processing Record 18 of Set 11 | quilpue
# City not found. Skipping...
# Processing Record 19 of Set 11 | waingapu
# City not found. Skipping...
# Processing Record 20 of Set 11 | tomari
# Processing Record 21 of Set 11 | eenhana
# Processing Record 22 of Set 11 | zhangjiakou
# Processing Record 23 of Set 11 | magdagachi
# Processing Record 24 of Set 11 | tatarani
# Processing Record 25 of Set 11 | kedrovyy
# Processing Record 26 of Set 11 | nador
# Processing Record 27 of Set 11 | borovoy
# Processing Record 28 of Set 11 | galveston
# Processing Record 29 of Set 11 | okha
# Processing Record 30 of Set 11 | nurota
# Processing Record 31 of Set 11 | padang
# Processing Record 32 of Set 11 | cacapava do sul
# City not found. Skipping...
# Processing Record 33 of Set 11 | havelock
# Processing Record 34 of Set 11 | tyumen
# Processing Record 35 of Set 11 | kupang
# Processing Record 36 of Set 11 | corcoran
# Processing Record 37 of Set 11 | grindavik
# City not found. Skipping...
# Processing Record 38 of Set 11 | puerto baquerizo moreno
# Processing Record 39 of Set 11 | moindou
# Processing Record 40 of Set 11 | lapa
# Processing Record 41 of Set 11 | salalah
# Processing Record 42 of Set 11 | loandjili
# Processing Record 43 of Set 11 | pusztavam
# Processing Record 44 of Set 11 | correntina
# Processing Record 45 of Set 11 | dzhebariki-khaya
# Processing Record 46 of Set 11 | synya
# Processing Record 47 of Set 11 | juneau
# Processing Record 48 of Set 11 | othaya
# Processing Record 49 of Set 11 | kensington
# Processing Record 1 of Set 12 | urshelskiy
# Processing Record 2 of Set 12 | killybegs
# Processing Record 3 of Set 12 | abu dhabi
# Processing Record 4 of Set 12 | fleetwood
# Processing Record 5 of Set 12 | kloulklubed
# Processing Record 6 of Set 12 | kaliua
# Processing Record 7 of Set 12 | vilyuysk
# Processing Record 8 of Set 12 | xining
# City not found. Skipping...
# Processing Record 9 of Set 12 | cuamba
# City not found. Skipping...
# Processing Record 10 of Set 12 | alcudia
# City not found. Skipping...
# Processing Record 11 of Set 12 | kieta
# Processing Record 12 of Set 12 | lima
# Processing Record 13 of Set 12 | moramanga
# Processing Record 14 of Set 12 | morondava
# Processing Record 15 of Set 12 | agucadoura
# Processing Record 16 of Set 12 | sicamous
# Processing Record 17 of Set 12 | ellsworth
# Processing Record 18 of Set 12 | yeniseysk
# Processing Record 19 of Set 12 | tuskegee
# Processing Record 20 of Set 12 | moyale
# Processing Record 21 of Set 12 | mackenzie
# Processing Record 22 of Set 12 | novoagansk
# Processing Record 23 of Set 12 | coquimbo
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City":cities_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
weather_df = pd.DataFrame(weather_dict)

# %%
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0       muros           0      ES  1616953602        44  42.7762   -9.0603
# 1    tessalit           0      ML  1616953603         6  20.1986    1.0114
# 2  kaitangata          97      NZ  1616953603        96 -46.2817  169.8464
# 3      dikson          45      RU  1616953603       100  73.5069   80.5464
# 4  chokurdakh          95      RU  1616953603       100  70.6333  147.9167
#
#    Max Temp  Wind Speed
# 0     68.00        3.00
# 1     82.89       10.45
# 2     52.07        3.18
# 3    -25.24        6.55
# 4    -16.37        4.50

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df.loc[weather_df['Humidity'] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#NO CITIES WITH HUMIDITY > 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c12465ffc552> in <module>
#       1 # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#       2 # Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# ----> 3 clean_df = weather_df[weather_df['Humidity'].isin('Humidity'> 100)==False]
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
