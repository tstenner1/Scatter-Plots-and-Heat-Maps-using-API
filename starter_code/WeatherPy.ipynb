# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
#!pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key
temp_units = "imperial"
#imperial for farenheight 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#lists for the dataframe
cities_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            cities_two.append(city)
        else:
            count_one += 1
            cities_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# City not found. Skipping...
# Processing Record 1 of Set 1 | monte patria
# Processing Record 2 of Set 1 | buraydah
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | cap-aux-meules
# Processing Record 8 of Set 1 | shahpur
# Processing Record 9 of Set 1 | ekhabi
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | wenling
# Processing Record 12 of Set 1 | pizarro
# Processing Record 13 of Set 1 | ambilobe
# Processing Record 14 of Set 1 | grand river south east
# Processing Record 15 of Set 1 | cidreira
# City not found. Skipping...
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | mamlyutka
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | grindavik
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | sao joao da barra
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | evensk
# Processing Record 31 of Set 1 | simbahan
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | jamame
# Processing Record 35 of Set 1 | vila velha
# Processing Record 36 of Set 1 | lasa
# Processing Record 37 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 42 of Set 1 | avarua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | moussoro
# Processing Record 45 of Set 1 | balkhash
# Processing Record 46 of Set 1 | lexington
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | antofagasta
# City not found. Skipping...
# Processing Record 49 of Set 1 | rapar
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | kirya
# Processing Record 3 of Set 2 | bonavista
# Processing Record 4 of Set 2 | north platte
# City not found. Skipping...
# Processing Record 5 of Set 2 | hilo
# City not found. Skipping...
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | yellowknife
# City not found. Skipping...
# Processing Record 8 of Set 2 | bull savanna
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | atar
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | san quintin
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | ambon
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | vestmannaeyjar
# Processing Record 17 of Set 2 | yelizovo
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | sitka
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | maple creek
# Processing Record 22 of Set 2 | darovskoy
# Processing Record 23 of Set 2 | chateaubelair
# Processing Record 24 of Set 2 | cacapava do sul
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | esmeraldas
# Processing Record 28 of Set 2 | karasjok
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | bozoum
# Processing Record 31 of Set 2 | dingle
# Processing Record 32 of Set 2 | shumskiy
# City not found. Skipping...
# Processing Record 33 of Set 2 | codrington
# Processing Record 34 of Set 2 | aberdeen
# Processing Record 35 of Set 2 | srednekolymsk
# Processing Record 36 of Set 2 | hobyo
# Processing Record 37 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 38 of Set 2 | otradnoye
# Processing Record 39 of Set 2 | palmer
# Processing Record 40 of Set 2 | coquimbo
# Processing Record 41 of Set 2 | anloga
# Processing Record 42 of Set 2 | leningradskiy
# Processing Record 43 of Set 2 | berlevag
# Processing Record 44 of Set 2 | key largo
# Processing Record 45 of Set 2 | traverse city
# Processing Record 46 of Set 2 | wanaka
# Processing Record 47 of Set 2 | priargunsk
# Processing Record 48 of Set 2 | haines junction
# Processing Record 49 of Set 2 | hannut
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | culfa
# Processing Record 3 of Set 3 | bubaque
# Processing Record 4 of Set 3 | hofn
# Processing Record 5 of Set 3 | mbuji-mayi
# Processing Record 6 of Set 3 | cape coast
# Processing Record 7 of Set 3 | maumere
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | saint-joseph
# City not found. Skipping...
# Processing Record 13 of Set 3 | touros
# City not found. Skipping...
# Processing Record 14 of Set 3 | valparaiso
# Processing Record 15 of Set 3 | katsuura
# Processing Record 16 of Set 3 | tuatapere
# Processing Record 17 of Set 3 | kolomna
# Processing Record 18 of Set 3 | seoul
# Processing Record 19 of Set 3 | whitehorse
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | ilulissat
# City not found. Skipping...
# Processing Record 22 of Set 3 | bathsheba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | nyagan
# Processing Record 25 of Set 3 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 26 of Set 3 | hami
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | tessalit
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | arlit
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | marienburg
# Processing Record 33 of Set 3 | harper
# Processing Record 34 of Set 3 | fort nelson
# Processing Record 35 of Set 3 | zemio
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | vallenar
# Processing Record 38 of Set 3 | beringovskiy
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | kahului
# City not found. Skipping...
# Processing Record 41 of Set 3 | fairbanks
# City not found. Skipping...
# Processing Record 42 of Set 3 | andilamena
# Processing Record 43 of Set 3 | deputatskiy
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | adrar
# Processing Record 46 of Set 3 | thompson
# City not found. Skipping...
# Processing Record 47 of Set 3 | emba
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | vorobyevka
# Processing Record 2 of Set 4 | chimore
# City not found. Skipping...
# Processing Record 3 of Set 4 | bengkulu
# Processing Record 4 of Set 4 | guanare
# Processing Record 5 of Set 4 | warrnambool
# Processing Record 6 of Set 4 | namibe
# Processing Record 7 of Set 4 | baie-comeau
# Processing Record 8 of Set 4 | qingyuan
# Processing Record 9 of Set 4 | auki
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | vostok
# Processing Record 13 of Set 4 | pauini
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | awbari
# Processing Record 16 of Set 4 | abu dhabi
# Processing Record 17 of Set 4 | margate
# Processing Record 18 of Set 4 | palmeirais
# City not found. Skipping...
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | sokoni
# Processing Record 21 of Set 4 | oranjemund
# Processing Record 22 of Set 4 | mys shmidta
# Processing Record 23 of Set 4 | aklavik
# Processing Record 24 of Set 4 | acapulco
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | enid
# Processing Record 27 of Set 4 | talara
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | galveston
# City not found. Skipping...
# Processing Record 30 of Set 4 | nhulunbuy
# Processing Record 31 of Set 4 | port lincoln
# Processing Record 32 of Set 4 | harlingen
# Processing Record 33 of Set 4 | san alberto
# Processing Record 34 of Set 4 | chuy
# Processing Record 35 of Set 4 | kralendijk
# Processing Record 36 of Set 4 | jaguarari
# Processing Record 37 of Set 4 | asau
# Processing Record 38 of Set 4 | khatanga
# City not found. Skipping...
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | puerto escondido
# Processing Record 41 of Set 4 | awjilah
# City not found. Skipping...
# Processing Record 42 of Set 4 | comodoro rivadavia
# Processing Record 43 of Set 4 | turayf
# Processing Record 44 of Set 4 | ozinki
# Processing Record 45 of Set 4 | ukiah
# Processing Record 46 of Set 4 | mogadouro
# Processing Record 47 of Set 4 | alta floresta
# Processing Record 48 of Set 4 | athens
# Processing Record 49 of Set 4 | tambura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 5 | preobrazheniye
# Processing Record 2 of Set 5 | crestview
# Processing Record 3 of Set 5 | orlik
# Processing Record 4 of Set 5 | kununurra
# Processing Record 5 of Set 5 | pangody
# Processing Record 6 of Set 5 | grand centre
# Processing Record 7 of Set 5 | sudak
# Processing Record 8 of Set 5 | puerto del rosario
# Processing Record 9 of Set 5 | laurel
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | tuktoyaktuk
# Processing Record 12 of Set 5 | moengo
# Processing Record 13 of Set 5 | tasiilaq
# Processing Record 14 of Set 5 | san cristobal
# Processing Record 15 of Set 5 | aswan
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | boksitogorsk
# Processing Record 18 of Set 5 | maniitsoq
# Processing Record 19 of Set 5 | marsa matruh
# Processing Record 20 of Set 5 | edremit
# Processing Record 21 of Set 5 | ranong
# Processing Record 22 of Set 5 | babanka
# City not found. Skipping...
# Processing Record 23 of Set 5 | kavaratti
# Processing Record 24 of Set 5 | beaufort
# Processing Record 25 of Set 5 | snezhnogorsk
# Processing Record 26 of Set 5 | kouango
# Processing Record 27 of Set 5 | ponta do sol
# City not found. Skipping...
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | udachnyy
# Processing Record 30 of Set 5 | socorro
# City not found. Skipping...
# Processing Record 31 of Set 5 | belmonte
# Processing Record 32 of Set 5 | victoria
# Processing Record 33 of Set 5 | katobu
# Processing Record 34 of Set 5 | lehigh acres
# Processing Record 35 of Set 5 | schrobenhausen
# Processing Record 36 of Set 5 | chapais
# City not found. Skipping...
# Processing Record 37 of Set 5 | ishigaki
# Processing Record 38 of Set 5 | toyooka
# Processing Record 39 of Set 5 | coelho neto
# Processing Record 40 of Set 5 | isla mujeres
# Processing Record 41 of Set 5 | muisne
# Processing Record 42 of Set 5 | ribeira grande
# Processing Record 43 of Set 5 | kaabong
# Processing Record 44 of Set 5 | texarkana
# Processing Record 45 of Set 5 | isangel
# Processing Record 46 of Set 5 | blythe
# Processing Record 47 of Set 5 | kamaishi
# Processing Record 48 of Set 5 | sciacca
# Processing Record 49 of Set 5 | butembo
# Processing Record 1 of Set 6 | howell
# Processing Record 2 of Set 6 | christchurch
# Processing Record 3 of Set 6 | cherepovets
# Processing Record 4 of Set 6 | ahuimanu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 6 | saldanha
# Processing Record 6 of Set 6 | kruisfontein
# Processing Record 7 of Set 6 | souillac
# City not found. Skipping...
# Processing Record 8 of Set 6 | ferme-neuve
# Processing Record 9 of Set 6 | zeya
# City not found. Skipping...
# Processing Record 10 of Set 6 | svetlaya
# Processing Record 11 of Set 6 | wasilla
# Processing Record 12 of Set 6 | odweyne
# Processing Record 13 of Set 6 | bilma
# Processing Record 14 of Set 6 | blackwater
# Processing Record 15 of Set 6 | tshikapa
# Processing Record 16 of Set 6 | marathon
# Processing Record 17 of Set 6 | pevek
# City not found. Skipping...
# Processing Record 18 of Set 6 | meulaboh
# City not found. Skipping...
# Processing Record 19 of Set 6 | dragodana
# Processing Record 20 of Set 6 | bandarbeyla
# Processing Record 21 of Set 6 | tiksi
# City not found. Skipping...
# Processing Record 22 of Set 6 | shelburne
# Processing Record 23 of Set 6 | biak
# City not found. Skipping...
# Processing Record 24 of Set 6 | bereznik
# Processing Record 25 of Set 6 | progreso
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | vizinga
# Processing Record 28 of Set 6 | patan
# Processing Record 29 of Set 6 | acajutla
# Processing Record 30 of Set 6 | moranbah
# Processing Record 31 of Set 6 | skjervoy
# Processing Record 32 of Set 6 | sept-iles
# Processing Record 33 of Set 6 | planeta rica
# Processing Record 34 of Set 6 | gazli
# Processing Record 35 of Set 6 | oros
# Processing Record 36 of Set 6 | cabo san lucas
# City not found. Skipping...
# Processing Record 37 of Set 6 | juba
# Processing Record 38 of Set 6 | banda aceh
# Processing Record 39 of Set 6 | sarangani
# Processing Record 40 of Set 6 | songjianghe
# Processing Record 41 of Set 6 | nyurba
# Processing Record 42 of Set 6 | amahai
# Processing Record 43 of Set 6 | karratha
# Processing Record 44 of Set 6 | sokoto
# Processing Record 45 of Set 6 | dunedin
# Processing Record 46 of Set 6 | hailin
# Processing Record 47 of Set 6 | camacha
# Processing Record 48 of Set 6 | mayumba
# Processing Record 49 of Set 6 | zahir pir
# Processing Record 1 of Set 7 | mnogovershinnyy
# Processing Record 2 of Set 7 | liuzhou
# Processing Record 3 of Set 7 | sharan
# Processing Record 4 of Set 7 | chute-aux-outardes
# Processing Record 5 of Set 7 | hovd
# Processing Record 6 of Set 7 | belyy yar
# Processing Record 7 of Set 7 | tiznit
# Processing Record 8 of Set 7 | surt
# Processing Record 9 of Set 7 | durres
# Processing Record 10 of Set 7 | tari
# Processing Record 11 of Set 7 | midland
# City not found. Skipping...
# Processing Record 12 of Set 7 | makat
# Processing Record 13 of Set 7 | nanortalik
# City not found. Skipping...
# Processing Record 14 of Set 7 | cayenne
# Processing Record 15 of Set 7 | ibiapina
# City not found. Skipping...
# Processing Record 16 of Set 7 | nara
# Processing Record 17 of Set 7 | opuwo
# City not found. Skipping...
# Processing Record 18 of Set 7 | kibala
# Processing Record 19 of Set 7 | atlantis
# Processing Record 20 of Set 7 | formoso do araguaia
# Processing Record 21 of Set 7 | toora-khem
# Processing Record 22 of Set 7 | bethel
# Processing Record 23 of Set 7 | itamarandiba
# Processing Record 24 of Set 7 | tabas
# Processing Record 25 of Set 7 | maraa
# Processing Record 26 of Set 7 | shimoda
# Processing Record 27 of Set 7 | ambunti
# Processing Record 28 of Set 7 | mabaruma
# Processing Record 29 of Set 7 | jardim
# Processing Record 30 of Set 7 | prieska
# Processing Record 31 of Set 7 | marrakesh
# Processing Record 32 of Set 7 | killybegs
# Processing Record 33 of Set 7 | porto novo
# Processing Record 34 of Set 7 | zakamensk
# Processing Record 35 of Set 7 | ambo
# Processing Record 36 of Set 7 | chernushka
# Processing Record 37 of Set 7 | steinbach
# City not found. Skipping...
# Processing Record 38 of Set 7 | nadvoitsy
# Processing Record 39 of Set 7 | brainerd
# Processing Record 40 of Set 7 | lorengau
# Processing Record 41 of Set 7 | konstantinovka
# Processing Record 42 of Set 7 | atambua
# Processing Record 43 of Set 7 | brae
# Processing Record 44 of Set 7 | pedernales
# Processing Record 45 of Set 7 | klaksvik
# Processing Record 46 of Set 7 | yumen
# Processing Record 47 of Set 7 | bretigny-sur-orge
# Processing Record 48 of Set 7 | kochubey
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 1 of Set 8 | san angelo
# Processing Record 2 of Set 8 | svetlogorsk
# Processing Record 3 of Set 8 | manyana
# Processing Record 4 of Set 8 | pangkalanbuun
# Processing Record 5 of Set 8 | avera
# Processing Record 6 of Set 8 | kovdor
# Processing Record 7 of Set 8 | thaba-tseka
# City not found. Skipping...
# Processing Record 8 of Set 8 | sicuani
# Processing Record 9 of Set 8 | saint-georges
# Processing Record 10 of Set 8 | noumea
# Processing Record 11 of Set 8 | shugurovo
# City not found. Skipping...
# Processing Record 12 of Set 8 | raha
# City not found. Skipping...
# Processing Record 13 of Set 8 | almeirim
# Processing Record 14 of Set 8 | tatawin
# City not found. Skipping...
# Processing Record 15 of Set 8 | paamiut
# Processing Record 16 of Set 8 | coihueco
# Processing Record 17 of Set 8 | portland
# Processing Record 18 of Set 8 | pangnirtung
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 8 | qazvin
# Processing Record 20 of Set 8 | jijiga
# Processing Record 21 of Set 8 | nchelenge
# Processing Record 22 of Set 8 | nadym
# Processing Record 23 of Set 8 | muli
# Processing Record 24 of Set 8 | krasnoselkup
# Processing Record 25 of Set 8 | san agustin
# Processing Record 26 of Set 8 | fuerte olimpo
# Processing Record 27 of Set 8 | vila
# Processing Record 28 of Set 8 | kargasok
# Processing Record 29 of Set 8 | rio grande
# Processing Record 30 of Set 8 | mananjary
# Processing Record 31 of Set 8 | seydi
# Processing Record 32 of Set 8 | uzice
# Processing Record 33 of Set 8 | binghamton
# Processing Record 34 of Set 8 | sioux lookout
# Processing Record 35 of Set 8 | yinchuan
# City not found. Skipping...
# Processing Record 36 of Set 8 | izhma
# Processing Record 37 of Set 8 | dunhua
# Processing Record 38 of Set 8 | rosamorada
# Processing Record 39 of Set 8 | hambantota
# City not found. Skipping...
# Processing Record 40 of Set 8 | ilhabela
# City not found. Skipping...
# Processing Record 41 of Set 8 | yerbogachen
# Processing Record 42 of Set 8 | faya
# Processing Record 43 of Set 8 | puerto madryn
# Processing Record 44 of Set 8 | tortoli
# Processing Record 45 of Set 8 | esso
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | akyab
# Processing Record 48 of Set 8 | vodnyy
# Processing Record 49 of Set 8 | beidao
# Processing Record 1 of Set 9 | esperance
# Processing Record 2 of Set 9 | oktyabrskoye
# Processing Record 3 of Set 9 | zaragoza
# Processing Record 4 of Set 9 | sampit
# City not found. Skipping...
# Processing Record 5 of Set 9 | yanam
# Processing Record 6 of Set 9 | dubuque
# Processing Record 7 of Set 9 | kloulklubed
# Processing Record 8 of Set 9 | beloha
# City not found. Skipping...
# Processing Record 9 of Set 9 | itaituba
# Processing Record 10 of Set 9 | kadoma
# Processing Record 11 of Set 9 | hailey
# Processing Record 12 of Set 9 | jiuquan
# Processing Record 13 of Set 9 | moshkovo
# Processing Record 14 of Set 9 | islahiye
# Processing Record 15 of Set 9 | zhigansk
# Processing Record 16 of Set 9 | batagay-alyta
# Processing Record 17 of Set 9 | porosozero
# Processing Record 18 of Set 9 | zonguldak
# Processing Record 19 of Set 9 | ndele
# City not found. Skipping...
# Processing Record 20 of Set 9 | belaya gora
# Processing Record 21 of Set 9 | ovalle
# Processing Record 22 of Set 9 | luzhou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 9 | constantine
# Processing Record 24 of Set 9 | bilibino
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | wukari
# Processing Record 27 of Set 9 | half moon bay
# Processing Record 28 of Set 9 | prince rupert
# Processing Record 29 of Set 9 | tumut
# City not found. Skipping...
# Processing Record 30 of Set 9 | yulara
# Processing Record 31 of Set 9 | nativitas
# Processing Record 32 of Set 9 | chippewa falls
# Processing Record 33 of Set 9 | samarai
# Processing Record 34 of Set 9 | rincon
# Processing Record 35 of Set 9 | sibi
# Processing Record 36 of Set 9 | grand gaube
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | rongcheng
# Processing Record 39 of Set 9 | scottsbluff
# Processing Record 40 of Set 9 | palora
# Processing Record 41 of Set 9 | iquitos
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | engels
# Processing Record 44 of Set 9 | roald
# Processing Record 45 of Set 9 | ouegoa
# Processing Record 46 of Set 9 | ugra
# Processing Record 47 of Set 9 | sur
# Processing Record 48 of Set 9 | taksimo
# Processing Record 49 of Set 9 | ulyanovsk
# Processing Record 1 of Set 10 | khartoum
# Processing Record 2 of Set 10 | buala
# Processing Record 3 of Set 10 | narrabri
# Processing Record 4 of Set 10 | aksu
# Processing Record 5 of Set 10 | saint-louis
# Processing Record 6 of Set 10 | sao miguel do araguaia
# Processing Record 7 of Set 10 | autazes
# Processing Record 8 of Set 10 | kapit
# Processing Record 9 of Set 10 | rafai
# Processing Record 10 of Set 10 | sinnamary
# Processing Record 11 of Set 10 | mikhaylovka
# Processing Record 12 of Set 10 | pisco
# Processing Record 13 of Set 10 | bandundu
# City not found. Skipping...
# Processing Record 14 of Set 10 | zalaegerszeg
# Processing Record 15 of Set 10 | narsaq
# Processing Record 16 of Set 10 | kiama
# Processing Record 17 of Set 10 | cerkezkoy
# Processing Record 18 of Set 10 | hamilton
# Processing Record 19 of Set 10 | yar-sale
# Processing Record 20 of Set 10 | log
# City not found. Skipping...
# Processing Record 21 of Set 10 | kharopon
# Processing Record 22 of Set 10 | tezu
# Processing Record 23 of Set 10 | campeche
# Processing Record 24 of Set 10 | salalah
# Processing Record 25 of Set 10 | shizunai
# Processing Record 26 of Set 10 | malinta
# Processing Record 27 of Set 10 | kutum
# Processing Record 28 of Set 10 | sistranda
# Processing Record 29 of Set 10 | ketchikan
# City not found. Skipping...
# Processing Record 30 of Set 10 | kanchanaburi
# Processing Record 31 of Set 10 | fare
# Processing Record 32 of Set 10 | alabino
# Processing Record 33 of Set 10 | kudahuvadhoo
# Processing Record 34 of Set 10 | borgarnes
# Processing Record 35 of Set 10 | tura
# Processing Record 36 of Set 10 | ixtapa
# Processing Record 37 of Set 10 | verkhnevilyuysk
# Processing Record 38 of Set 10 | tual
# Processing Record 39 of Set 10 | dejen
# Processing Record 40 of Set 10 | oksovskiy
# Processing Record 41 of Set 10 | fethiye
# Processing Record 42 of Set 10 | mishan
# Processing Record 43 of Set 10 | kyakhta
# Processing Record 44 of Set 10 | havoysund
# Processing Record 45 of Set 10 | gizo
# Processing Record 46 of Set 10 | lufilufi
# Processing Record 47 of Set 10 | tonj
# City not found. Skipping...
# Processing Record 48 of Set 10 | tutoia
# Processing Record 49 of Set 10 | chernyshevskiy
# Processing Record 1 of Set 11 | martan-chu
# Processing Record 2 of Set 11 | san isidro
# Processing Record 3 of Set 11 | waitara
# Processing Record 4 of Set 11 | albanel
# Processing Record 5 of Set 11 | bethanien
# Processing Record 6 of Set 11 | tucuma
# Processing Record 7 of Set 11 | ostersund
# Processing Record 8 of Set 11 | vagur
# Processing Record 9 of Set 11 | gobabis
# Processing Record 10 of Set 11 | kampene
# Processing Record 11 of Set 11 | chimbote
# Processing Record 12 of Set 11 | swellendam
# Processing Record 13 of Set 11 | mlowo
# Processing Record 14 of Set 11 | dubbo
# Processing Record 15 of Set 11 | richards bay
# Processing Record 16 of Set 11 | suez
# Processing Record 17 of Set 11 | saint-pierre
# Processing Record 18 of Set 11 | ranchuelo
# Processing Record 19 of Set 11 | sobolevo
# Processing Record 20 of Set 11 | pahrump
# Processing Record 21 of Set 11 | tongchuan
# Processing Record 22 of Set 11 | sheopur
# Processing Record 23 of Set 11 | lagoa
# City not found. Skipping...
# Processing Record 24 of Set 11 | constitucion
# City not found. Skipping...
# Processing Record 25 of Set 11 | northam
# City not found. Skipping...
# Processing Record 26 of Set 11 | mana
# Processing Record 27 of Set 11 | olinda
# Processing Record 28 of Set 11 | beira
# Processing Record 29 of Set 11 | flinders
# Processing Record 30 of Set 11 | merritt island
# Processing Record 31 of Set 11 | kamiiso
# City not found. Skipping...
# Processing Record 32 of Set 11 | luanda
# Processing Record 33 of Set 11 | bandrele
# Processing Record 34 of Set 11 | brodokalmak
# Processing Record 35 of Set 11 | tolbazy
# Processing Record 36 of Set 11 | caravelas
# Processing Record 37 of Set 11 | dargaville
# Processing Record 38 of Set 11 | kawalu
# Processing Record 39 of Set 11 | villa rica
# Processing Record 40 of Set 11 | alekseyevka
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City":cities_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
weather_df = pd.DataFrame(weather_dict)

# %%
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0  monte patria           0      FR  1617067996        81  42.4687    9.3916
# 1      buraydah           0      SA  1617067996        31  26.3260   43.9750
# 2        albany           0      US  1617067708        35  42.6001  -73.9662
# 3        hobart           0      AU  1617067997        48 -42.8794  147.3294
# 4       ushuaia          20      AR  1617067888        76 -54.8000  -68.3000
#
#    Max Temp  Wind Speed
# 0      54.0        5.75
# 1      59.0       12.66
# 2      39.0        1.01
# 3      66.0       10.36
# 4      50.0        7.36

# %%
weather_df.to_csv("weatherpy_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df.loc[weather_df['Humidity'] > 100]
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#NO CITIES WITH HUMIDITY > 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed in mph")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
L=0
northern = weather_df.query(f"Lat >= {L}")
southern = weather_df.query(f"Lat <= {L}")

# %%
# Define function for creating linear agression and scatter plot
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (0,25)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,5)

# Save the figure
plt.savefig("../Images/Northern  - Max Temperature vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: -0.8743658401791049

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (-55,90)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,6)

# Save fig 
plt.savefig("../Images/Southern Hemisphere - Max Temperature vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.4982153479637337

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (45,10)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,7)

# Save fig
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.3491588946444046

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (-55,15)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,8)

#savefig
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.26367888166851894

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (20,40)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,9)

#save fig 
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.2164187417101866

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-55,50)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,10)

#savefig
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.37674988664319525

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (0,30)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,11)

#savefig
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: 0.10371308562400076

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (-25,33)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,12)

#savefig
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: -0.15056215962982306
